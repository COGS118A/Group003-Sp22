# %% [markdown]
# # KNN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
HYG = pd.read_csv("hygdata_v3.csv")

# %%
HYG
# Out:
#             id  hip        hd  hr       gl   bf proper         ra        dec  \
# 0            0  NaN       NaN NaN      NaN  NaN    Sol   0.000000   0.000000
# 1            1  1.0  224700.0 NaN      NaN  NaN    NaN   0.000060   1.089009
# 2            2  2.0  224690.0 NaN      NaN  NaN    NaN   0.000283 -19.498840
# 3            3  3.0  224699.0 NaN      NaN  NaN    NaN   0.000335  38.859279
# 4            4  4.0  224707.0 NaN      NaN  NaN    NaN   0.000569 -51.893546
# ...        ...  ...       ...  ..      ...  ...    ...        ...        ...
# 119609  119611  NaN       NaN NaN  NN 4381  NaN    NaN  23.963895  38.629391
# 119610  119612  NaN       NaN NaN  NN 4385  NaN    NaN  23.996567  47.762093
# 119611  119613  NaN       NaN NaN  NN 4386  NaN    NaN  23.996218 -44.067905
# 119612  119614  NaN       NaN NaN  NN 4387  NaN    NaN  23.997386 -34.111986
# 119613  119615  NaN       NaN NaN   Gl 915  NaN    NaN   0.036059 -43.165974
#
# ...

# %% [markdown]
# # DATA Cleaning

# %%
HYG = HYG.drop(columns = ["id", "hip", "hd", "hr", "gl", "bf", "ra", "dec", "proper", "pmra", "pmdec", "rv",
                          "bayer", "x", "y", "z", "vx", "vy", "vz", "rarad", "decrad", "pmrarad", "pmdecrad",
                          "flam", "con", "comp", "comp_primary", "base", "var", "var_min", "var_max"])

# %%
star_type = ["O", "B", "A", "F", "G", "K", "M"]
HYG = HYG.dropna(axis = 0, how = "any")
y = HYG["spect"]
X = HYG.drop(columns = ["spect", "dist"])

# %%
def change_type(string):
    return string[0].upper()
y = y.apply(change_type)

# %% [markdown]
# # KNN

# %%
kf = KFold(n_splits = 5, shuffle = True, random_state = 42)
model = KNeighborsClassifier(n_neighbors = 5)
scores_knn = cross_val_score(model, X, y, scoring = 'accuracy', cv = kf)

# %%
scores_knn
# Out:
# array([0.67641832, 0.67728514, 0.67243098, 0.68109912, 0.67598492])

# %% [markdown]
# # SVC

# %%
kf = KFold(n_splits = 5, shuffle = True, random_state = 42)
clf = make_pipeline(StandardScaler(), SVC(gamma = 'auto'))
scores_svc = cross_val_score(clf, X, y, scoring = 'accuracy', cv = kf)

# %%
scores_svc
# Out:
# array([0.75781216, 0.75815889, 0.75503836, 0.75573181, 0.7592424 ])
